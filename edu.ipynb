# %% [markdown]
# # Introduction

# %% [markdown]
# For this project we were told to find the best neighborhood within Pittsburgh based on a metric that we had to choose on our own. Obviously there are several valid factors to determine this, but one factor that I felt would make it fairly easy to find this out was Educational Attainment. The dataset contained variables of the total number of people who have completed nursery school all the way to completing a doctorate degree and also the total popiulation of people wihtin that neighborhood. Using these statistics I was able to deduce the best neighborhood based on the highest category of education that was attained. Some alternatives I explored for this project were wage/salary pay per neighborhood and employment rates.

# %% [markdown]
# # My Metric

# %% [markdown]
# My metric, Educational Attainment, has variables that measured the total amount of people who completed different grades starting from nursery school to their doctorate degree. Towards the end the certain features I focused on were the new variable that was the sum of grades of people in highschool, those who have completed some college, and those who have attained an associate's degree or above. To find the best neighborhood, I calculated the percentage of the category/new variable associate column and this is where and how I based my overall conclusion of the best neighborhood.

# %%
import pandas as pd
edu = pd.read_csv("edu.csv", index_col = "Neighborhood")
edu.head(10)
for col in edu.columns:
    print(col)
# Out:
# Id
# Estimate; Total:
# Margin of Error; Total:
# Estimate; Total: - No schooling completed
# Margin of Error; Total: - No schooling completed
# Estimate; Total: - Nursery school
# Margin of Error; Total: - Nursery school
# Estimate; Total: - Kindergarten
# Margin of Error; Total: - Kindergarten
# Estimate; Total: - 1st grade
# Margin of Error; Total: - 1st grade
# Estimate; Total: - 2nd grade
# Margin of Error; Total: - 2nd grade
# Estimate; Total: - 3rd grade
# Margin of Error; Total: - 3rd grade
# Estimate; Total: - 4th grade
# Margin of Error; Total: - 4th grade
# Estimate; Total: - 5th grade
# Margin of Error; Total: - 5th grade
# Estimate; Total: - 6th grade
# Margin of Error; Total: - 6th grade
# Estimate; Total: - 7th grade
# Margin of Error; Total: - 7th grade
# Estimate; Total: - 8th grade
# Margin of Error; Total: - 8th grade
# Estimate; Total: - 9th grade
# Margin of Error; Total: - 9th grade
# Estimate; Total: - 10th grade
# Margin of Error; Total: - 10th grade
# Estimate; Total: - 11th grade
# Margin of Error; Total: - 11th grade
# Estimate; Total: - 12th grade, no diploma
# Margin of Error; Total: - 12th grade, no diploma
# Estimate; Total: - Regular high school diploma
# Margin of Error; Total: - Regular high school diploma
# Estimate; Total: - GED or alternative credential
# Margin of Error; Total: - GED or alternative credential
# Estimate; Total: - Some college, less than 1 year
# Margin of Error; Total: - Some college, less than 1 year
# Estimate; Total: - Some college, 1 or more years, no degree
# Margin of Error; Total: - Some college, 1 or more years, no degree
# Estimate; Total: - Associate's degree
# Margin of Error; Total: - Associate's degree
# Estimate; Total: - Bachelor's degree
# Margin of Error; Total: - Bachelor's degree
# Estimate; Total: - Master's degree
# Margin of Error; Total: - Master's degree
# Estimate; Total: - Professional school degree
# Margin of Error; Total: - Professional school degree
# Estimate; Total: - Doctorate degree
# Margin of Error; Total: - Doctorate degree

# %%
edu = pd.read_csv("edu.csv", index_col = "Neighborhood")
edu.head(10)
# Out:
#                    Id  Estimate; Total:  Margin of Error; Total:  \
# Neighborhood
# Allegheny Center    1             791.0               140.000000
# Allegheny West      2             283.0                92.000000
# Allentown           3            1611.0               247.786198
# Arlington           4            1271.0               224.512806
# Arlington Heights   5             182.0               108.000000
# Banksville          6            3368.0               390.564975
# Bedford Dwellings   7             674.0                88.000000
# Beechview           8            5834.0               512.740675
# Beltzhoover         9            1347.0               246.300629
# Bloomfield         10            6603.0               431.270217
#
#                    Estimate; Total: - No schooling completed  \
# Neighborhood
# Allegheny Center                                         7.0
# Allegheny West                                           0.0
# Allentown                                               14.0
# Arlington                                               37.0
# Arlington Heights                                        0.0
# Banksville                                               4.0
# Bedford Dwellings                                       21.0
# Beechview                                              111.0
# Beltzhoover                                             14.0
# Bloomfield                                              42.0
#
#                    Margin of Error; Total: - No schooling completed  \
# Neighborhood
# Allegheny Center                                          11.000000
# Allegheny West                                            10.000000
# Allentown                                                 24.494897
# Arlington                                                 39.560081
# Arlington Heights                                         10.000000
# Banksville                                                19.078784
# Bedford Dwellings                                         17.000000
# Beechview                                                107.373181
# Beltzhoover                                               26.457513
# Bloomfield                                                32.863353
#
#                    Estimate; Total: - Nursery school  \
# Neighborhood
# Allegheny Center                                 0.0
# Allegheny West                                   0.0
# Allentown                                        0.0
# Arlington                                        0.0
# Arlington Heights                                0.0
# Banksville                                       0.0
# Bedford Dwellings                                0.0
# Beechview                                        0.0
# Beltzhoover                                      0.0
# Bloomfield                                       0.0
#
#                    Margin of Error; Total: - Nursery school  \
# Neighborhood
# Allegheny Center                                  10.000000
# Allegheny West                                    10.000000
# Allentown                                         17.320508
# Arlington                                         17.320508
# Arlington Heights                                 10.000000
# Banksville                                        20.000000
# Bedford Dwellings                                 10.000000
# Beechview                                         31.622777
# Beltzhoover                                       20.000000
# Bloomfield                                        31.622777
#
#                    Estimate; Total: - Kindergarten  \
# Neighborhood
# Allegheny Center                               0.0
# Allegheny West                                 0.0
# Allentown                                      0.0
# Arlington                                      0.0
# Arlington Heights                              0.0
# Banksville                                     0.0
# Bedford Dwellings                              0.0
# Beechview                                      0.0
# Beltzhoover                                    0.0
# Bloomfield                                     0.0
#
#                    Margin of Error; Total: - Kindergarten  \
# Neighborhood
# Allegheny Center                                10.000000
# Allegheny West                                  10.000000
# Allentown                                       17.320508
# Arlington                                       17.320508
# Arlington Heights                               10.000000
# Banksville                                      20.000000
# Bedford Dwellings                               10.000000
# Beechview                                       31.622777
# Beltzhoover                                     20.000000
# Bloomfield                                      31.622777
#
#                    Estimate; Total: - 1st grade  ...  \
# Neighborhood                                     ...
# Allegheny Center                            0.0  ...
# Allegheny West                              0.0  ...
# Allentown                                   6.0  ...
# Arlington                                   0.0  ...
# Arlington Heights                           0.0  ...
# Banksville                                  0.0  ...
# Bedford Dwellings                           0.0  ...
# Beechview                                   0.0  ...
# Beltzhoover                                 0.0  ...
# Bloomfield                                  0.0  ...
#
#                    Estimate; Total: - Associate's degree  \
# Neighborhood
# Allegheny Center                                    53.0
# Allegheny West                                      25.0
# Allentown                                           59.0
# Arlington                                          124.0
# Arlington Heights                                    0.0
# Banksville                                         366.0
# Bedford Dwellings                                   37.0
# Beechview                                          621.0
# Beltzhoover                                         77.0
# Bloomfield                                         450.0
#
#                    Margin of Error; Total: - Associate's degree  \
# Neighborhood
# Allegheny Center                                      38.000000
# Allegheny West                                        19.000000
# Allentown                                             43.046487
# Arlington                                             54.378304
# Arlington Heights                                     10.000000
# Banksville                                           142.365726
# Bedford Dwellings                                     27.000000
# Beechview                                            138.852440
# Beltzhoover                                           60.348985
# Bloomfield                                           134.469327
#
#                    Estimate; Total: - Bachelor's degree  \
# Neighborhood
# Allegheny Center                                  176.0
# Allegheny West                                    121.0
# Allentown                                          72.0
# Arlington                                          84.0
# Arlington Heights                                   0.0
# Banksville                                        718.0
# Bedford Dwellings                                  37.0
# Beechview                                        1089.0
# Beltzhoover                                        50.0
# Bloomfield                                       1704.0
#
#                    Margin of Error; Total: - Bachelor's degree  \
# Neighborhood
# Allegheny Center                                     73.000000
# Allegheny West                                       61.000000
# Allentown                                            50.049975
# Arlington                                            46.173586
# Arlington Heights                                    10.000000
# Banksville                                          193.705963
# Bedford Dwellings                                    29.000000
# Beechview                                           223.539706
# Beltzhoover                                          33.645208
# Bloomfield                                          252.713276
#
#                    Estimate; Total: - Master's degree  \
# Neighborhood
# Allegheny Center                                 74.0
# Allegheny West                                   12.0
# Allentown                                        38.0
# Arlington                                        13.0
# Arlington Heights                                 0.0
# Banksville                                      504.0
# Bedford Dwellings                                 0.0
# Beechview                                       293.0
# Beltzhoover                                      80.0
# Bloomfield                                     1072.0
#
#                    Margin of Error; Total: - Master's degree  \
# Neighborhood
# Allegheny Center                                   66.000000
# Allegheny West                                     13.000000
# Allentown                                          28.635642
# Arlington                                          13.038405
# Arlington Heights                                  10.000000
# Banksville                                        202.763409
# Bedford Dwellings                                  10.000000
# Beechview                                          98.229324
# Beltzhoover                                        52.316345
# Bloomfield                                        185.429232
#
#                    Estimate; Total: - Professional school degree  \
# Neighborhood
# Allegheny Center                                            88.0
# Allegheny West                                              13.0
# Allentown                                                   30.0
# Arlington                                                    2.0
# Arlington Heights                                            0.0
# Banksville                                                  98.0
# Bedford Dwellings                                            0.0
# Beechview                                                   86.0
# Beltzhoover                                                  0.0
# Bloomfield                                                 210.0
#
#                    Margin of Error; Total: - Professional school degree  \
# Neighborhood
# Allegheny Center                                           50.000000
# Allegheny West                                             16.000000
# Allentown                                                  29.748950
# Arlington                                                  14.696938
# Arlington Heights                                          10.000000
# Banksville                                                 68.410526
# Bedford Dwellings                                          10.000000
# Beechview                                                  63.694584
# Beltzhoover                                                20.000000
# Bloomfield                                                 79.113842
#
#                    Estimate; Total: - Doctorate degree  \
# Neighborhood
# Allegheny Center                                   6.0
# Allegheny West                                     6.0
# Allentown                                          0.0
# Arlington                                          0.0
# Arlington Heights                                  0.0
# Banksville                                         0.0
# Bedford Dwellings                                  0.0
# Beechview                                         18.0
# Beltzhoover                                        0.0
# Bloomfield                                       217.0
#
#                    Margin of Error; Total: - Doctorate degree
# Neighborhood
# Allegheny Center                                     9.000000
# Allegheny West                                       9.000000
# Allentown                                           17.320508
# Arlington                                           17.320508
# Arlington Heights                                   10.000000
# Banksville                                          20.000000
# Bedford Dwellings                                   10.000000
# Beechview                                           41.036569
# Beltzhoover                                         20.000000
# Bloomfield                                          78.460181
#
# [10 rows x 51 columns]

# %%
import pandas as pd
edu = pd.read_csv("edu.csv", index_col = "Neighborhood")
edu['eighth_below'] = edu['Estimate; Total: - Nursery school'] + edu['Estimate; Total: - Kindergarten'] + edu['Estimate; Total: - 1st grade'] + edu['Estimate; Total: - 2nd grade'] + edu['Estimate; Total: - 3rd grade'] + edu['Estimate; Total: - 4th grade'] + edu['Estimate; Total: - 5th grade'] + edu['Estimate; Total: - 6th grade'] + edu['Estimate; Total: - 7th grade'] + edu['Estimate; Total: - 8th grade']
temp = edu[['Estimate; Total: - Nursery school', 'Estimate; Total: - Kindergarten', 'Estimate; Total: - 1st grade', 'Estimate; Total: - 2nd grade', 'Estimate; Total: - 3rd grade', 'Estimate; Total: - 4th grade', 'Estimate; Total: - 5th grade', 'Estimate; Total: - 6th grade', 'Estimate; Total: - 7th grade', 'Estimate; Total: - 8th grade', 'eighth_below']]
temp.head(10)
# Out:
#                    Estimate; Total: - Nursery school  \
# Neighborhood
# Allegheny Center                                 0.0
# Allegheny West                                   0.0
# Allentown                                        0.0
# Arlington                                        0.0
# Arlington Heights                                0.0
# Banksville                                       0.0
# Bedford Dwellings                                0.0
# Beechview                                        0.0
# Beltzhoover                                      0.0
# Bloomfield                                       0.0
#
#                    Estimate; Total: - Kindergarten  \
# Neighborhood
# Allegheny Center                               0.0
# Allegheny West                                 0.0
# Allentown                                      0.0
# Arlington                                      0.0
# Arlington Heights                              0.0
# Banksville                                     0.0
# Bedford Dwellings                              0.0
# Beechview                                      0.0
# Beltzhoover                                    0.0
# Bloomfield                                     0.0
#
#                    Estimate; Total: - 1st grade  Estimate; Total: - 2nd grade  \
# Neighborhood
# Allegheny Center                            0.0                           0.0
# Allegheny West                              0.0                           0.0
# Allentown                                   6.0                           0.0
# Arlington                                   0.0                           0.0
# Arlington Heights                           0.0                           0.0
# Banksville                                  0.0                           0.0
# Bedford Dwellings                           0.0                           0.0
# Beechview                                   0.0                           0.0
# Beltzhoover                                 0.0                           0.0
# Bloomfield                                  0.0                           4.0
#
#                    Estimate; Total: - 3rd grade  Estimate; Total: - 4th grade  \
# Neighborhood
# Allegheny Center                            0.0                           0.0
# Allegheny West                              0.0                           0.0
# Allentown                                   0.0                           0.0
# Arlington                                   0.0                           0.0
# Arlington Heights                           0.0                           0.0
# Banksville                                  0.0                           0.0
# Bedford Dwellings                          10.0                           0.0
# Beechview                                   0.0                           0.0
# Beltzhoover                                 0.0                           0.0
# Bloomfield                                 12.0                           9.0
#
#                    Estimate; Total: - 5th grade  Estimate; Total: - 6th grade  \
# Neighborhood
# Allegheny Center                            0.0                           0.0
# Allegheny West                              0.0                          13.0
# Allentown                                   0.0                           0.0
# Arlington                                   0.0                           6.0
# Arlington Heights                           0.0                           0.0
# Banksville                                  0.0                           0.0
# Bedford Dwellings                           0.0                           0.0
# Beechview                                   0.0                           9.0
# Beltzhoover                                 0.0                           9.0
# Bloomfield                                 32.0                           5.0
#
#                    Estimate; Total: - 7th grade  Estimate; Total: - 8th grade  \
# Neighborhood
# Allegheny Center                            0.0                           0.0
# Allegheny West                              0.0                           9.0
# Allentown                                   0.0                          10.0
# Arlington                                   0.0                          25.0
# Arlington Heights                           0.0                           0.0
# Banksville                                  0.0                           7.0
# Bedford Dwellings                           0.0                           0.0
# Beechview                                  46.0                          70.0
# Beltzhoover                                 0.0                           0.0
# Bloomfield                                  7.0                          26.0
#
#                    eighth_below
# Neighborhood
# Allegheny Center            0.0
# Allegheny West             22.0
# Allentown                  16.0
# Arlington                  31.0
# Arlington Heights           0.0
# Banksville                  7.0
# Bedford Dwellings          10.0
# Beechview                 125.0
# Beltzhoover                 9.0
# Bloomfield                 95.0

# %%
edu['some_highschool'] = edu['Estimate; Total: - 9th grade'] + edu['Estimate; Total: - 10th grade'] + edu['Estimate; Total: - 11th grade'] + edu['Estimate; Total: - 12th grade, no diploma']
temp = edu[['Estimate; Total: - 9th grade', 'Estimate; Total: - 10th grade', 'Estimate; Total: - 11th grade', 'Estimate; Total: - 12th grade, no diploma', 'some_highschool']]
temp.head(10)
# Out:
#                    Estimate; Total: - 9th grade  \
# Neighborhood
# Allegheny Center                            6.0
# Allegheny West                              6.0
# Allentown                                  12.0
# Arlington                                  19.0
# Arlington Heights                           7.0
# Banksville                                 33.0
# Bedford Dwellings                           0.0
# Beechview                                  24.0
# Beltzhoover                                18.0
# Bloomfield                                 43.0
#
#                    Estimate; Total: - 10th grade  \
# Neighborhood
# Allegheny Center                            32.0
# Allegheny West                               0.0
# Allentown                                   33.0
# Arlington                                   35.0
# Arlington Heights                           52.0
# Banksville                                 106.0
# Bedford Dwellings                           29.0
# Beechview                                   50.0
# Beltzhoover                                 92.0
# Bloomfield                                  38.0
#
#                    Estimate; Total: - 11th grade  \
# Neighborhood
# Allegheny Center                            28.0
# Allegheny West                               0.0
# Allentown                                    9.0
# Arlington                                   31.0
# Arlington Heights                            8.0
# Banksville                                  46.0
# Bedford Dwellings                           61.0
# Beechview                                  125.0
# Beltzhoover                                111.0
# Bloomfield                                  43.0
#
#                    Estimate; Total: - 12th grade, no diploma  some_highschool
# Neighborhood
# Allegheny Center                                        22.0             88.0
# Allegheny West                                           0.0              6.0
# Allentown                                               40.0             94.0
# Arlington                                               15.0            100.0
# Arlington Heights                                       63.0            130.0
# Banksville                                               0.0            185.0
# Bedford Dwellings                                        6.0             96.0
# Beechview                                              114.0            313.0
# Beltzhoover                                             49.0            270.0
# Bloomfield                                              83.0            207.0

# %%
edu['highschool'] =  edu['Estimate; Total: - Regular high school diploma']+edu['Estimate; Total: - GED or alternative credential']
temp = edu[['Estimate; Total: - Regular high school diploma', 'Estimate; Total: - GED or alternative credential', 'highschool']]
temp.head(10)
# Out:
#                    Estimate; Total: - Regular high school diploma  \
# Neighborhood
# Allegheny Center                                            156.0
# Allegheny West                                               35.0
# Allentown                                                   603.0
# Arlington                                                   439.0
# Arlington Heights                                            17.0
# Banksville                                                  867.0
# Bedford Dwellings                                           259.0
# Beechview                                                  1552.0
# Beltzhoover                                                 360.0
# Bloomfield                                                 1398.0
#
#                    Estimate; Total: - GED or alternative credential  \
# Neighborhood
# Allegheny Center                                                0.0
# Allegheny West                                                 15.0
# Allentown                                                     217.0
# Arlington                                                     116.0
# Arlington Heights                                               9.0
# Banksville                                                     90.0
# Bedford Dwellings                                             102.0
# Beechview                                                     395.0
# Beltzhoover                                                   143.0
# Bloomfield                                                    229.0
#
#                    highschool
# Neighborhood
# Allegheny Center        156.0
# Allegheny West           50.0
# Allentown               820.0
# Arlington               555.0
# Arlington Heights        26.0
# Banksville              957.0
# Bedford Dwellings       361.0
# Beechview              1947.0
# Beltzhoover             503.0
# Bloomfield             1627.0

# %%
edu['some_college'] = edu['Estimate; Total: - Some college, less than 1 year'] + edu['Estimate; Total: - Some college, 1 or more years, no degree']
temp = edu[['Estimate; Total: - Some college, less than 1 year', 'Estimate; Total: - Some college, 1 or more years, no degree', 'some_college']]
temp.head(10)
# Out:
#                    Estimate; Total: - Some college, less than 1 year  \
# Neighborhood
# Allegheny Center                                                33.0
# Allegheny West                                                  10.0
# Allentown                                                      131.0
# Arlington                                                       74.0
# Arlington Heights                                                6.0
# Banksville                                                     172.0
# Bedford Dwellings                                               31.0
# Beechview                                                      420.0
# Beltzhoover                                                     97.0
# Bloomfield                                                     290.0
#
#                    Estimate; Total: - Some college, 1 or more years, no degree  \
# Neighborhood
# Allegheny Center                                               110.0
# Allegheny West                                                  18.0
# Allentown                                                      337.0
# Arlington                                                      251.0
# Arlington Heights                                               20.0
# Banksville                                                     357.0
# Bedford Dwellings                                               81.0
# Beechview                                                      811.0
# Beltzhoover                                                    247.0
# Bloomfield                                                     689.0
#
#                    some_college
# Neighborhood
# Allegheny Center          143.0
# Allegheny West             28.0
# Allentown                 468.0
# Arlington                 325.0
# Arlington Heights          26.0
# Banksville                529.0
# Bedford Dwellings         112.0
# Beechview                1231.0
# Beltzhoover               344.0
# Bloomfield                979.0

# %%
edu['assoc_above'] = edu['Estimate; Total: - Associate\'s degree'] + edu['Estimate; Total: - Bachelor\'s degree'] + edu['Estimate; Total: - Master\'s degree'] + edu['Estimate; Total: - Professional school degree'] + edu['Estimate; Total: - Doctorate degree']
temp = edu[['Estimate; Total: - Associate\'s degree', 'Estimate; Total: - Bachelor\'s degree', 'Estimate; Total: - Master\'s degree', 'Estimate; Total: - Professional school degree', 'Estimate; Total: - Doctorate degree', 'assoc_above']]
temp.head(10)
# Out:
#                    Estimate; Total: - Associate's degree  \
# Neighborhood
# Allegheny Center                                    53.0
# Allegheny West                                      25.0
# Allentown                                           59.0
# Arlington                                          124.0
# Arlington Heights                                    0.0
# Banksville                                         366.0
# Bedford Dwellings                                   37.0
# Beechview                                          621.0
# Beltzhoover                                         77.0
# Bloomfield                                         450.0
#
#                    Estimate; Total: - Bachelor's degree  \
# Neighborhood
# Allegheny Center                                  176.0
# Allegheny West                                    121.0
# Allentown                                          72.0
# Arlington                                          84.0
# Arlington Heights                                   0.0
# Banksville                                        718.0
# Bedford Dwellings                                  37.0
# Beechview                                        1089.0
# Beltzhoover                                        50.0
# Bloomfield                                       1704.0
#
#                    Estimate; Total: - Master's degree  \
# Neighborhood
# Allegheny Center                                 74.0
# Allegheny West                                   12.0
# Allentown                                        38.0
# Arlington                                        13.0
# Arlington Heights                                 0.0
# Banksville                                      504.0
# Bedford Dwellings                                 0.0
# Beechview                                       293.0
# Beltzhoover                                      80.0
# Bloomfield                                     1072.0
#
#                    Estimate; Total: - Professional school degree  \
# Neighborhood
# Allegheny Center                                            88.0
# Allegheny West                                              13.0
# Allentown                                                   30.0
# Arlington                                                    2.0
# Arlington Heights                                            0.0
# Banksville                                                  98.0
# Bedford Dwellings                                            0.0
# Beechview                                                   86.0
# Beltzhoover                                                  0.0
# Bloomfield                                                 210.0
#
#                    Estimate; Total: - Doctorate degree  assoc_above
# Neighborhood
# Allegheny Center                                   6.0        397.0
# Allegheny West                                     6.0        177.0
# Allentown                                          0.0        199.0
# Arlington                                          0.0        223.0
# Arlington Heights                                  0.0          0.0
# Banksville                                         0.0       1686.0
# Bedford Dwellings                                  0.0         74.0
# Beechview                                         18.0       2107.0
# Beltzhoover                                        0.0        207.0
# Bloomfield                                       217.0       3653.0

# %%
edu['eighth_below_per'] = (edu['eighth_below']/edu['Estimate; Total:'])*100
edu['some_highschool_per'] = (edu['some_highschool']/edu['Estimate; Total:'])*100
edu['highschool_per'] = (edu['highschool']/edu['Estimate; Total:'])*100
edu['some_college_per'] = (edu['some_college']/edu['Estimate; Total:'])*100
edu['assoc_above_per'] = (edu['assoc_above']/edu['Estimate; Total:'])*100
edu['total_population'] = edu['Estimate; Total:']


edu_new = edu.loc[:, ['total_population', 'eighth_below_per',  'some_highschool_per', 'highschool_per','some_college_per',  'assoc_above_per']]

# %%
edu_new.sort_values('highschool_per', ascending=False).head(10)
# Out:
#                        total_population  eighth_below_per  \
# Neighborhood
# West End                          112.0          0.000000
# Esplen                            235.0          0.000000
# Bedford Dwellings                 674.0          1.483680
# Windgap                          1026.0          0.877193
# Allentown                        1611.0          0.993172
# Mt. Oliver                        381.0          0.000000
# Hays                              277.0          0.000000
# Lincoln Place                    2565.0          0.000000
# Spring Hill-City View            1615.0          3.095975
# Bluff                            1725.0          1.623188
#
#                        some_highschool_per  highschool_per  some_college_per  \
# Neighborhood
# West End                          0.000000       58.928571         11.607143
# Esplen                            5.106383       57.872340         22.553191
# Bedford Dwellings                14.243323       53.560831         16.617211
# Windgap                           3.801170       52.534113         22.807018
# Allentown                         5.834885       50.900062         29.050279
# Mt. Oliver                        1.574803       50.393701         20.997375
# Hays                              5.776173       49.819495         19.494585
# Lincoln Place                     7.368421       48.927875         15.516569
# Spring Hill-City View             9.721362       48.854489         12.383901
# Bluff                            14.724638       48.811594         21.333333
#
#                        assoc_above_per
# Neighborhood
# West End                     29.464286
# Esplen                       14.468085
# Bedford Dwellings            10.979228
# Windgap                      18.810916
# Allentown                    12.352576
# Mt. Oliver                   25.196850
# Hays                         24.909747
# Lincoln Place                26.432749
# Spring Hill-City View        25.201238
# Bluff                        12.637681

# %%
edu_new.sort_values('some_college_per', ascending=False).head(10)
# Out:
#                 total_population  eighth_below_per  some_highschool_per  \
# Neighborhood
# East Hills                1852.0          0.000000             9.179266
# Garfield                  2330.0          1.158798            11.416309
# Ridgemont                  246.0          0.000000            12.195122
# Allentown                 1611.0          0.993172             5.834885
# Manchester                1415.0          0.636042             5.229682
# Middle Hill               1293.0          4.176334            16.009281
# Homewood North            1775.0          2.873239             9.295775
# Chartiers City             356.0          0.000000            10.674157
# South Oakland             1256.0          1.433121             3.821656
# Arlington                 1271.0          2.439024             7.867821
#
#                 highschool_per  some_college_per  assoc_above_per
# Neighborhood
# East Hills           39.362851         32.775378        18.196544
# Garfield             34.721030         32.446352        19.742489
# Ridgemont            19.512195         30.487805        37.804878
# Allentown            50.900062         29.050279        12.352576
# Manchester           20.989399         28.621908        42.897527
# Middle Hill          32.018561         27.996906        18.020108
# Homewood North       35.154930         26.985915        24.676056
# Chartiers City       35.112360         26.685393        27.528090
# South Oakland        21.735669         26.114650        42.993631
# Arlington            43.666404         25.570417        17.545240

# %%
sorted_neighborhoods = edu_new.sort_values('assoc_above_per', ascending=False).head(10)
print(sorted_neighborhoods)
# Out:
#                      total_population  eighth_below_per  some_highschool_per  \
# Neighborhood
# South Shore                       8.0          0.000000             0.000000
# Strip District                  611.0          0.000000             0.000000
# Shadyside                      9414.0          1.041003             0.966645
# Squirrel Hill North            5494.0          0.964689             0.910084
# Regent Square                   774.0          0.000000             1.808786
# Point Breeze                   4022.0          0.795624             1.268026
# North Shore                     159.0          0.000000             0.000000
# Point Breeze North             1527.0          0.000000             0.851343
# Squirrel Hill South           11164.0          0.850949             1.728771
# North Oakland                  2937.0          0.817160             5.107252
#
#                      highschool_per  some_college_per  assoc_above_per
# Neighborhood
# South Shore                0.000000          0.000000       100.000000
# Strip District             3.436989          6.710311        89.852700
# Shadyside                  7.074570          6.384109        83.736987
# Squirrel Hill North        5.988351          8.281762        83.527485
# Regent Square              8.785530          8.010336        80.361757
# Point Breeze               8.304326         10.343113        79.288911
# North Shore                5.660377         15.723270        78.616352
# Point Breeze North        11.918795          9.692207        77.537656
# Squirrel Hill South       12.343246          8.957363        76.039054
# North Oakland              7.456588         11.270003        73.544433

# %%
sorted_neighborhoods['assoc_above_per'].plot.bar()

# %% [markdown]
# # BEST NEIGHBORHOOD & CONCLUSION

# %% [markdown]
# After analyzing the educational attainment dataset, I was able to find what represents the best neighborhood in Pittsburgh. After sorting the data I specifically looked and calculated the percentage of those who earned an assiciate's degree or higher and based my conlcusions from these numbers. When looking at the listed out percentages in the table above, it is easy to assume that South Shore would represent as the best neighborhood in Pittsburgh, although this is technically not the case. The total population of South Shore is 8 which means the percentage of those who attained an associates degree or higher is not the most reliable. When reanalyzing the percentages, but keeping the population in mind the best neighborhood in Pittsburgh is Shadyside. Once again the extremely high population foloowing a relatively high percentage shows that the neighborhood is the best because of its educational aspect. It can be assumed with this data that Shadyside most likely has more resources to focus on its neighborhood's education and prioritize those living in the neighborhood itself.
