# %%
import pandas as pd

# %% [markdown]
# #### **Introduction**

# %%
data = pd.read_csv("MD_death_rate.csv", index_col="NEIGHBORHOOD" )
data.head(20)
# Out:
#                            BLACKdeaths  Black MD AGE AT DEATH  WHITEdeaths  \
# NEIGHBORHOOD
# SOUTH SHORE                        0.0                    0.0          0.0
# CHATEAU                            0.0                    0.0          2.0
# NORTH SHORE                        0.0                    0.0          4.0
# ALLEGHENY WEST                     3.0                    NaN          4.0
# SAINT CLAIR                        5.0                   67.5          5.0
# WEST END                           5.0                   76.7          9.0
# ESPLEN                             3.0                    NaN         13.0
# ARLINGTON HEIGHTS                 10.0                   55.0          7.0
# STRIP DISTRICT                     7.0                   76.7         12.0
# FAIRYWOOD                         11.0                   62.5          9.0
# HAYS                               1.0                    NaN         23.0
# ...

# %%
#table1= pd.DataFrame(data)
data1=data.drop(["BLACKdeaths", "Black MD AGE AT DEATH", "WHITEdeaths", "White MD AGE AT DEATH"], axis=1)

data_df = pd.DataFrame(data1)

data_df.set_index("NEIGHBORHOOD")




#fin_table = pd.merge(table, table1, left_on ="TOTAL MD AGE AT DEATH", right_on = "TOTALdeaths*")
print(data_df)
#print(table1)
#print(fin_table)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MD_death_rate.csv'
#
# The above exception was the direct cause of the following exception:
#
# ...
