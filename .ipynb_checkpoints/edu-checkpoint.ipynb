# %% [markdown]
# Introduction

# %% [markdown]
# **Introduce the project, your approach, talk about the process of how you came up with the metric and some alternatives you may have explored.**

# %% [markdown]
# *these are vairbales from said dataset to show what is being factored in before analyzing

# %%
import pandas as pd
edu = pd.read_csv("edu.csv", index_col = "Neighborhood")
edu.head(10)
for col in edu.columns:
    print(col)
# Out:
# Id
# Estimate; Total:
# Margin of Error; Total:
# Estimate; Total: - No schooling completed
# Margin of Error; Total: - No schooling completed
# Estimate; Total: - Nursery school
# Margin of Error; Total: - Nursery school
# Estimate; Total: - Kindergarten
# Margin of Error; Total: - Kindergarten
# Estimate; Total: - 1st grade
# Margin of Error; Total: - 1st grade
# Estimate; Total: - 2nd grade
# Margin of Error; Total: - 2nd grade
# Estimate; Total: - 3rd grade
# Margin of Error; Total: - 3rd grade
# Estimate; Total: - 4th grade
# Margin of Error; Total: - 4th grade
# Estimate; Total: - 5th grade
# Margin of Error; Total: - 5th grade
# Estimate; Total: - 6th grade
# Margin of Error; Total: - 6th grade
# Estimate; Total: - 7th grade
# Margin of Error; Total: - 7th grade
# Estimate; Total: - 8th grade
# Margin of Error; Total: - 8th grade
# Estimate; Total: - 9th grade
# Margin of Error; Total: - 9th grade
# Estimate; Total: - 10th grade
# Margin of Error; Total: - 10th grade
# ...

# %%
edu = pd.read_csv("edu.csv", index_col = "Neighborhood")
edu.head(10)
# Out:
#                    Id  Estimate; Total:  Margin of Error; Total:  \
# Neighborhood
# Allegheny Center    1             791.0               140.000000
# Allegheny West      2             283.0                92.000000
# Allentown           3            1611.0               247.786198
# Arlington           4            1271.0               224.512806
# Arlington Heights   5             182.0               108.000000
# Banksville          6            3368.0               390.564975
# Bedford Dwellings   7             674.0                88.000000
# Beechview           8            5834.0               512.740675
# Beltzhoover         9            1347.0               246.300629
# Bloomfield         10            6603.0               431.270217
#
#                    Estimate; Total: - No schooling completed  \
# Neighborhood
# Allegheny Center                                         7.0
# Allegheny West                                           0.0
# ...

# %%
import pandas as pd
edu = pd.read_csv("edu.csv", index_col = "Neighborhood")
edu['Seventh_Below'] = edu['Estimate; Total: - Nursery school'] + edu['Estimate; Total: - Kindergarten'] + edu['Estimate; Total: - 1st grade'] + edu['Estimate; Total: - 2nd grade'] + edu['Estimate; Total: - 3rd grade'] + edu['Estimate; Total: - 4th grade'] + edu['Estimate; Total: - 5th grade'] + edu['Estimate; Total: - 6th grade'] + edu['Estimate; Total: - 7th grade']
edu = edu[['Estimate; Total: - Nursery school', 'Estimate; Total: - Kindergarten', 'Estimate; Total: - 1st grade', 'Estimate; Total: - 2nd grade', 'Estimate; Total: - 3rd grade', 'Estimate; Total: - 4th grade', 'Estimate; Total: - 5th grade', 'Estimate; Total: - 6th grade', 'Estimate; Total: - 7th grade', 'Seventh_Below']]
edu.head(10)
# Out:
#                    Estimate; Total: - Nursery school  \
# Neighborhood
# Allegheny Center                                 0.0
# Allegheny West                                   0.0
# Allentown                                        0.0
# Arlington                                        0.0
# Arlington Heights                                0.0
# Banksville                                       0.0
# Bedford Dwellings                                0.0
# Beechview                                        0.0
# Beltzhoover                                      0.0
# Bloomfield                                       0.0
#
#                    Estimate; Total: - Kindergarten  \
# Neighborhood
# Allegheny Center                               0.0
# Allegheny West                                 0.0
# Allentown                                      0.0
# Arlington                                      0.0
# Arlington Heights                              0.0
# ...

# %%
import pandas as pd
edu = pd.read_csv("edu.csv", index_col = "Neighborhood")
edu = edu[['Estimate; Total: - 8th grade']]
edu.head(10)
# Out:
#                    Estimate; Total: - 8th grade
# Neighborhood
# Allegheny Center                            0.0
# Allegheny West                              9.0
# Allentown                                  10.0
# Arlington                                  25.0
# Arlington Heights                           0.0
# Banksville                                  7.0
# Bedford Dwellings                           0.0
# Beechview                                  70.0
# Beltzhoover                                 0.0
# Bloomfield                                 26.0

# %%
import pandas as pd
edu = pd.read_csv("edu.csv", index_col = "Neighborhood")
edu['eighth_highschool'] = edu['Estimate; Total: - 8th grade'] + edu['Estimate; Total: - 9th grade'] + edu['Estimate; Total: - 10th grade'] + edu['Estimate; Total: - 11th grade'] + edu['Estimate; Total: - 12th grade'] + edu['Regular high school diploma']
edu = edu[['Estimate; Total: - 8th grade', 'Estimate; Total: - 9th grade', 'Estimate; Total: - 10th grade', 'Estimate; Total: - 11th grade', 'Estimate; Total: - 12th grade', 'Regular high school diploma', 'eighth_highschool']]
edu.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Estimate; Total: - 12th grade'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# Here im taking each of the different categories I specifically want to group together and summing them up

# %%
#edu = pd.read_csv("edu.csv", index_col = "Neighborhood")
#df = pd.DataFrame(data)
#address = ['Estimate; Total: - 9th grade', 'Estimate; Total: - 10th grade', 'Estimate; Total: - 11th grade', 'Estimate; Total: - 12th grade']

edu['Seventh_Below'] = edu['Estimate; Total: - Nursery school'] + edu['Estimate; Total: - Kindergarten'] + edu['Estimate; Total: - 1st grade'] + edu['Estimate; Total: - 2nd grade'] + edu['Estimate; Total: - 3rd grade'] + edu['Estimate; Total: - 4th grade'] + edu['Estimate; Total: - 5th grade'] + edu['Estimate; Total: - 6th grade'] + edu['Estimate; Total: - 7th grade']
edu.head(15)
#edu[col]
edu['eighth'] = edu['Estimate; Total: - 8th grade']
edu['HighSchool'] = edu['Estimate; Total: - 9th grade'] + edu['Estimate; Total: - 10th grade'] + edu['Estimate; Total: - 11th grade'] + edu['Estimate; Total: - 12th grade'] + edu['Regular high school diploma']
#edu['some_edu'] = edu['Estimate; Total: - GED or alternative credential'] + edu['Estimate; Total: - Some college, less than 1 year'] + edu['Estimate; Total: - Some college, 1 or more years, no degree']
#edu['assoc'] = edu['Estimate; Total: - Associate degree']
#edu['bach_above'] = edu['Estimate; Total: - Bachelor degree'] + edu['Estimate; Total: - Master degree'] + edu['Estimate; Total: - Professional school degree'] + edu['Estimate; Total: - Doctorate degree']
#col_keep = ['id', 'total_surveyed','no_school','seventh_below', 'eighth', 'some_hs', 'hs', 'some_college', 'assoc', 'bach_above']
#col_per = ['no_school','seventh_below', 'eighth', 'some_hs', 'hs', 'some_college', 'assoc', 'bach_above'] #all col to make percentages of
#edu[new_col] = edu['seventh_below']
#edu.head(10)
#edu[col_keep]

#address = ['Estimate; Total: - Nursery school']
# Out:
#                       Id  Estimate; Total:  Margin of Error; Total:  \
# Neighborhood
# Allegheny Center       1             791.0               140.000000
# Allegheny West         2             283.0                92.000000
# Allentown              3            1611.0               247.786198
# Arlington              4            1271.0               224.512806
# Arlington Heights      5             182.0               108.000000
# Banksville             6            3368.0               390.564975
# Bedford Dwellings      7             674.0                88.000000
# Beechview              8            5834.0               512.740675
# Beltzhoover            9            1347.0               246.300629
# Bloomfield            10            6603.0               431.270217
# Bluff                 11            1725.0               262.554756
# Bon Air               12             595.0               104.000000
# Brighton Heights      13            5389.0               360.897492
# ...

# %%
edu['eighth'] = edu['Estimate; Total: - 8th grade']
edu.head(15)
# Out:
#                       Id  Estimate; Total:  Margin of Error; Total:  \
# Neighborhood
# Allegheny Center       1             791.0               140.000000
# Allegheny West         2             283.0                92.000000
# Allentown              3            1611.0               247.786198
# Arlington              4            1271.0               224.512806
# Arlington Heights      5             182.0               108.000000
# Banksville             6            3368.0               390.564975
# Bedford Dwellings      7             674.0                88.000000
# Beechview              8            5834.0               512.740675
# Beltzhoover            9            1347.0               246.300629
# Bloomfield            10            6603.0               431.270217
# Bluff                 11            1725.0               262.554756
# Bon Air               12             595.0               104.000000
# Brighton Heights      13            5389.0               360.897492
# ...

# %%
edu['Seventh_Below'] = edu['Estimate; Total: - Nursery school'] + edu['Estimate; Total: - Kindergarten'] + edu['Estimate; Total: - 1st grade'] + edu['Estimate; Total: - 2nd grade'] + edu['Estimate; Total: - 3rd grade'] + edu['Estimate; Total: - 4th grade'] + edu['Estimate; Total: - 5th grade'] + edu['Estimate; Total: - 6th grade'] + edu['Estimate; Total: - 7th grade']
edu.head(10)
# Out:
#                    Id  Estimate; Total:  Margin of Error; Total:  \
# Neighborhood
# Allegheny Center    1             791.0               140.000000
# Allegheny West      2             283.0                92.000000
# Allentown           3            1611.0               247.786198
# Arlington           4            1271.0               224.512806
# Arlington Heights   5             182.0               108.000000
# Banksville          6            3368.0               390.564975
# Bedford Dwellings   7             674.0                88.000000
# Beechview           8            5834.0               512.740675
# Beltzhoover         9            1347.0               246.300629
# Bloomfield         10            6603.0               431.270217
#
#                    Estimate; Total: - No schooling completed  \
# Neighborhood
# Allegheny Center                                         7.0
# Allegheny West                                           0.0
# ...

# %% [markdown]
# now i layout the column of all the neighborrhoods and just the total population column

# %% [markdown]
# now do the total of each of the seperate categories like the totlal you found for seventh and below divided by the total population
# keep doing this for each of the seperate new variables you made

# %% [markdown]
# now return this as a new column called percentedu_per

# %%
edu['seventh_below'] = edu['Estimate; Total: - Nursery school'] + edu['Estimate; Total: - Kindergarten'] + edu['Estimate; Total: - 1st grade'] + edu['Estimate; Total: - 2nd grade'] + edu['Estimate; Total: - 3rd grade'] + edu['Estimate; Total: - 4th grade'] + edu['Estimate; Total: - 5th grade'] + edu['Estimate; Total: - 6th grade'] + edu['Estimate; Total: - 7th grade'] 
#edu['eighth'] = edu['Estimate; Total: - 8th grade']
#edu['eighth'] =

col_keep = ['id', 'total_surveyed','no_school','seventh_below', 'eighth', 'some_hs', 'hs', 'some_college', 'assoc', 'bach_above']
col_per = ['no_school','seventh_below', 'eighth', 'some_hs', 'hs', 'some_college', 'assoc', 'bach_above']



#for col in col_per:
col ='seventh_below'
new_colnm = col + '_per'
print(new_colnm)
edu[new_colnm] = edu['col']
edu.head(10)
# Out:
# seventh_below_per
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'col'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
include graph of last ten
