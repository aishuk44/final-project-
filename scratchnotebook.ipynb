# %%
import pandas as pd
emp = pd.read_csv("emp.csv", index_col = "Neighborhood")
emp.head(10)
# Out:
#                    Sector # Population (2010)  \
# Neighborhood
# Allegheny Center          3               933
# Allegheny West            3               462
# Allentown                 6             2,500
# Arlington                 7             1,869
# Arlington Heights         7               244
# Banksville                5             4,144
# Bedford Dwellings        15             1,202
# Beechview                 5             7,974
# Beltzhoover               6             1,925
# Bloomfield               12             8,442
#
#                   Total Age 16+ N'hood Residents Employed (2010 Est.)  \
# Neighborhood
# Allegheny Center                                                 386
# Allegheny West                                                   151
# Allentown                                                        858
# Arlington                                                        685
# Arlington Heights                                                 72
# ...

# %%
import pandas as pd
emp = pd.read_csv("emp.csv", index_col = "Neighborhood")
for col in emp.columns:
    print(col)
# Out:
# Sector #
# Population (2010)
# Total Age 16+ N'hood Residents Employed (2010 Est.)
# Resident Jobs: Construction
# Resident Jobs: Manufacturing
# Resident Jobs: Retail Trade
# Resident Jobs: Transportation, warehousing, utilities
# Resident Jobs: Information
# Resident Jobs: Finance, insurance, real estate
# Resident Jobs: Prof, scientific, admin, and waste mgmt
# Resident Jobs: Educ, health and social svc
# Resident Jobs: Arts, ent, recreation, accommodation and food services
# Resident Jobs: Public admin
# Resident Jobs: Other
# Total # Jobs Located in N'hood (2000 - latest yr. avail.)
# Jobs in 'Hood: Construction
# Jobs in 'Hood: Manufacturing
# Jobs in 'Hood: Retail trade
# Jobs in 'Hood: Transport, warehousing, utilities
# Jobs in 'Hood: Information
# Jobs in 'Hood: Finance, insurance, real estate
# Jobs in 'Hood: Prof, scientific, admin, and waste mgmt
# Jobs in 'Hood: Educ, health, and social svc
# Jobs in 'Hood: Arts, ent, recreation, accommodation and food services
# ...

# %%
unique function for distinct neighborgood

# %% [markdown]
# - figure out the education categories /milestones
# - 7th grade and below -- some gradeschool completed
# - 8th grade completed
# - some highschool
# - highschool completed
# - some college
# - asssocitae degree
# - bachelors + master and above
# - no schooling completed
#
# 1. show all the variables im using if possible
# 2. find the sum of each row i.e of total surveyed population / concesus
# 3. for each education type find percentage by n/row sum times 100 **dont look at margin of error variables
# 4. keep doing this for each variable
# -- sort by different metrics of what makes neighborhood best based on edu
#     - highschool
#     - some college
#     - associate
#     - bach + above
